# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Transformation_2.csv")
df
# Out:
#         Vehicle_ID  Frame_ID  Total_Frames   Global_Time   Local_X  \
# 0             1760      5683           243  1.113430e+12  0.953414
# 1             1760      5682           243  1.113430e+12  0.961339
# 2             1760      5681           243  1.113430e+12  0.969264
# 3             1760      5680           243  1.113430e+12  0.982370
# 4             1760      5679           243  1.113430e+12  0.988771
# ...            ...       ...           ...           ...       ...
# 341701        1755      7322           388  1.113438e+12  0.874166
# 341702        1755      7323           388  1.113438e+12  0.869594
# 341703        1755      7324           388  1.113438e+12  0.865937
# 341704        1755      7325           388  1.113438e+12  0.861974
# 341705        1755      7326           388  1.113438e+12  0.858622
#
#            Local_Y     Global_X     Global_Y  v_Length  v_Width  ...  \
# 0       425.375767  6042644.327  2134449.877   6.49224      8.5  ...
# 1       423.323483  6042645.392  2134443.458   6.49224      8.5  ...
# 2       421.265679  6042646.466  2134436.985   6.49224      8.5  ...
# 3       419.201729  6042647.579  2134430.379   6.49224      8.5  ...
# 4       417.131926  6042648.745  2134423.299   6.49224      8.5  ...
# ...            ...          ...          ...       ...      ...  ...
# 341701  439.571071  6042636.659  2134495.641   5.42544      8.4  ...
# 341702  440.984301  6042635.877  2134500.351   5.42544      8.4  ...
# 341703  442.401238  6042635.103  2134505.014   5.42544      8.4  ...
# 341704  443.822373  6042634.346  2134509.574   5.42544      8.4  ...
# 341705  445.250404  6042633.605  2134514.042   5.42544      8.4  ...
#
#         v_Acc_preceding  Lane_ID_preceding  Space_Headway_preceding  \
# 0             -3.043688                  1                33.634680
# 1             -2.833217                  1                34.192464
# 2             -2.703060                  1                34.475928
# 3             -2.366147                  1                34.847784
# 4             -1.977164                  1                35.295840
# ...                 ...                ...                      ...
# 341701        -0.428896                  1                33.086040
# 341702        -0.702400                  1                33.278064
# 341703        -0.960326                  1                33.521904
# 341704        -1.217816                  1                33.677352
# 341705        -1.480312                  1                34.094928
#
#         Time_Headway_preceding   L-F_Pair  pair_Time_Duration  \
# 0                         1.58  1754-1760                 0.0
# 1                         1.56  1754-1760                 0.1
# 2                         1.63  1754-1760                 0.2
# 3                         1.64  1754-1760                 0.3
# 4                         1.67  1754-1760                 0.4
# ...                        ...        ...                 ...
# 341701                    2.39  1749-1755                32.4
# 341702                    2.43  1749-1755                32.5
# 341703                    2.44  1749-1755                32.6
# 341704                    2.41  1749-1755                32.7
# 341705                    2.39  1749-1755                32.8
#
#         total_pair_duration  Vehicle_Class  Space_Gap Difference_of_speed
# 0                      11.6  Heavy Vehicle  36.277296            1.090135
# 1                      11.6  Heavy Vehicle  36.030408            1.327031
# 2                      11.6  Heavy Vehicle  35.920680            1.527489
# 3                      11.6  Heavy Vehicle  35.832288            1.700222
# 4                      11.6  Heavy Vehicle  35.814000            1.844612
# ...                     ...            ...        ...                 ...
# 341701                 32.8            Car  16.773144            1.164830
# 341702                 32.8            Car  16.684752            1.071146
# 341703                 32.8            Car  16.605504            0.951025
# 341704                 32.8            Car  16.565880            0.795200
# 341705                 32.8            Car  16.596360            0.569349
#
# [341706 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341706 entries, 0 to 341705
# Data columns (total 36 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Vehicle_ID               341706 non-null  int64
#  1   Frame_ID                 341706 non-null  int64
#  2   Total_Frames             341706 non-null  int64
#  3   Global_Time              341706 non-null  float64
#  4   Local_X                  341706 non-null  float64
#  5   Local_Y                  341706 non-null  float64
#  6   Global_X                 341706 non-null  float64
#  7   Global_Y                 341706 non-null  float64
#  8   v_Length                 341706 non-null  float64
#  9   v_Width                  341706 non-null  float64
#  10  v_Class                  341706 non-null  int64
#  11  v_Vel                    341706 non-null  float64
#  12  v_Acc                    341706 non-null  float64
#  13  Lane_ID                  341706 non-null  int64
#  14  Preceding                341706 non-null  int64
#  15  Following                341706 non-null  int64
#  16  Space_Headway            341706 non-null  float64
#  17  Time_Headway             341706 non-null  float64
#  18  Location                 341706 non-null  object
#  19  Period                   341706 non-null  object
#  20  Vehicle_ID_preceding     341706 non-null  int64
#  21  Global_Time_preceding    341706 non-null  float64
#  22  v_Length_preceding       341706 non-null  float64
#  23  v_Width_preceding        341706 non-null  float64
#  24  v_Class_preceding        341706 non-null  int64
#  25  v_Vel_preceding          341706 non-null  float64
#  26  v_Acc_preceding          341706 non-null  float64
#  27  Lane_ID_preceding        341706 non-null  int64
#  28  Space_Headway_preceding  341706 non-null  float64
#  29  Time_Headway_preceding   341706 non-null  float64
#  30  L-F_Pair                 341706 non-null  object
#  31  pair_Time_Duration       341706 non-null  float64
#  32  total_pair_duration      341706 non-null  float64
#  33  Vehicle_Class            341706 non-null  object
#  34  Space_Gap                341706 non-null  float64
#  35  Difference_of_speed      341706 non-null  float64
# dtypes: float64(22), int64(10), object(4)
# memory usage: 93.9+ MB

# %%
df = df.drop(['Total_Frames', 'Global_Time', 'Local_X', 'Global_X', 'Global_Y','Following','Global_Time_preceding','v_Width_preceding'],axis=1)

# %%
#import matplotlib.pyplot as plt
#import seaborn as sns 
#corr_df =df.corr()
#top_corr_feature = corr_df.index

#plt.figure(figsize = (20,20))

#plot = sns.heatmap(df[top_corr_feature].corr() , annot = True ,  cmap = "RdYlGn" )

# %%
import Cleanup
clean = Cleanup.clean()

# %%
test_df, train_df = clean.train_test_pair(df, 0.2)
train_df.to_csv('train_df.csv')
train_df
# Out:
#         Vehicle_ID  Frame_ID     Local_Y  v_Length  v_Width  v_Class  \
# 0             1760      5683  425.375767   6.49224      8.5        3
# 1             1760      5682  423.323483   6.49224      8.5        3
# 2             1760      5681  421.265679   6.49224      8.5        3
# 3             1760      5680  419.201729   6.49224      8.5        3
# 4             1760      5679  417.131926   6.49224      8.5        3
# ...            ...       ...         ...       ...      ...      ...
# 341682        1749      7307  440.807041   5.73024      8.0        2
# 341683        1749      7308  442.227949   5.73024      8.0        2
# 341685        1749      7309  443.650723   5.73024      8.0        2
# 341687        1749      7310  445.075004   5.73024      8.0        2
# 341690        1749      7311  446.500490   5.73024      8.0        2
#
#             v_Vel     v_Acc  Lane_ID  Preceding  ...  v_Acc_preceding  \
# 0       20.498565 -0.283574        1       1754  ...        -3.043688
# 1       20.547120 -0.474961        1       1754  ...        -2.833217
# 2       20.608958 -0.491087        1       1754  ...        -2.703060
# 3       20.670048 -0.463286        1       1754  ...        -2.366147
# 4       20.725999 -0.777079        1       1754  ...        -1.977164
# ...           ...       ...      ...        ...  ...              ...
# 341682  14.199165  0.212091        1       1747  ...        -2.206973
# 341683  14.218998  0.184687        1       1747  ...        -2.400602
# 341685  14.236483  0.165098        1       1747  ...        -2.595519
# 341687  14.249134  0.087992        1       1747  ...        -2.790514
# 341690  14.260588  0.141147        1       1747  ...        -2.978038
#
#         Lane_ID_preceding Space_Headway_preceding Time_Headway_preceding  \
# 0                       1               33.634680                   1.58
# 1                       1               34.192464                   1.56
# 2                       1               34.475928                   1.63
# 3                       1               34.847784                   1.64
# 4                       1               35.295840                   1.67
# ...                   ...                     ...                    ...
# 341682                  1               22.817328                   1.45
# 341683                  1               22.774656                   1.44
# 341685                  1               22.765512                   1.44
# 341687                  1               22.863048                   1.45
# 341690                  1               22.652736                   1.44
#
#          L-F_Pair  pair_Time_Duration  total_pair_duration  Vehicle_Class  \
# 0       1754-1760                 0.0                 11.6  Heavy Vehicle
# 1       1754-1760                 0.1                 11.6  Heavy Vehicle
# 2       1754-1760                 0.2                 11.6  Heavy Vehicle
# 3       1754-1760                 0.3                 11.6  Heavy Vehicle
# 4       1754-1760                 0.4                 11.6  Heavy Vehicle
# ...           ...                 ...                  ...            ...
# 341682  1747-1749                32.9                 33.3            Car
# 341683  1747-1749                33.0                 33.3            Car
# 341685  1747-1749                33.1                 33.3            Car
# 341687  1747-1749                33.2                 33.3            Car
# 341690  1747-1749                33.3                 33.3            Car
#
#         Space_Gap  Difference_of_speed
# 0       36.277296             1.090135
# 1       36.030408             1.327031
# 2       35.920680             1.527489
# 3       35.832288             1.700222
# 4       35.814000             1.844612
# ...           ...                  ...
# 341682  26.862024             0.672852
# 341683  27.008328             0.422254
# 341685  27.166824             0.154545
# 341687  27.322272            -0.127859
# 341690  27.462480            -0.428224
#
# [269953 rows x 28 columns]

# %%
test_df.to_csv('test_df.csv')
test_df
# Out:
#         Vehicle_ID  Frame_ID     Local_Y  v_Length  v_Width  v_Class  \
# 2029          1728      5460  199.176151   4.99872      4.9        2
# 2030          1728      5459  197.063314   4.99872      4.9        2
# 2031          1728      5458  194.950155   4.99872      4.9        2
# 2032          1728      5457  192.837061   4.99872      4.9        2
# 2033          1728      5456  190.724215   4.99872      4.9        2
# ...            ...       ...         ...       ...      ...      ...
# 341701        1755      7322  439.571071   5.42544      8.4        2
# 341702        1755      7323  440.984301   5.42544      8.4        2
# 341703        1755      7324  442.401238   5.42544      8.4        2
# 341704        1755      7325  443.822373   5.42544      8.4        2
# 341705        1755      7326  445.250404   5.42544      8.4        2
#
#             v_Vel     v_Acc  Lane_ID  Preceding  ...  v_Acc_preceding  \
# 2029    21.125748 -0.136463        1       1719  ...        -0.755640
# 2030    21.130999 -0.060278        1       1719  ...        -0.727227
# 2031    21.132177  0.016128        1       1719  ...        -0.726696
# 2032    21.129697  0.076817        1       1719  ...        -0.732732
# 2033    21.127232  0.005575        1       1719  ...        -0.639452
# ...           ...       ...      ...        ...  ...              ...
# 341701  14.113733  0.372719        1       1749  ...        -0.428896
# 341702  14.150868  0.369981        1       1749  ...        -0.702400
# 341703  14.187875  0.370157        1       1749  ...        -0.960326
# 341704  14.234822  0.568790        1       1749  ...        -1.217816
# 341705  14.325803  1.250826        1       1749  ...        -1.480312
#
#         Lane_ID_preceding Space_Headway_preceding Time_Headway_preceding  \
# 2029                    1               70.954392                   3.57
# 2030                    1               71.128128                   3.54
# 2031                    1               71.341488                   3.46
# 2032                    1               71.615808                   3.39
# 2033                    1               72.036432                   3.28
# ...                   ...                     ...                    ...
# 341701                  1               33.086040                   2.39
# 341702                  1               33.278064                   2.43
# 341703                  1               33.521904                   2.44
# 341704                  1               33.677352                   2.41
# 341705                  1               34.094928                   2.39
#
#          L-F_Pair  pair_Time_Duration  total_pair_duration  Vehicle_Class  \
# 2029    1719-1728                 0.0                 17.7            Car
# 2030    1719-1728                 0.1                 17.7            Car
# 2031    1719-1728                 0.2                 17.7            Car
# 2032    1719-1728                 0.3                 17.7            Car
# 2033    1719-1728                 0.4                 17.7            Car
# ...           ...                 ...                  ...            ...
# 341701  1749-1755                32.4                 32.8            Car
# 341702  1749-1755                32.5                 32.8            Car
# 341703  1749-1755                32.6                 32.8            Car
# 341704  1749-1755                32.7                 32.8            Car
# 341705  1749-1755                32.8                 32.8            Car
#
#         Space_Gap  Difference_of_speed
# 2029    29.970984            -0.380847
# 2030    30.144720            -0.281815
# 2031    30.233112            -0.221334
# 2032    30.263592            -0.156960
# 2033    30.144720            -0.093838
# ...           ...                  ...
# 341701  16.773144             1.164830
# 341702  16.684752             1.071146
# 341703  16.605504             0.951025
# 341704  16.565880             0.795200
# 341705  16.596360             0.569349
#
# [71753 rows x 28 columns]

# %%
 def create_prediction_columns( df, n):
        '''
        create the prediction pair by shifting the actual data up by the mentioned number(0.1*n seconds) to create the timeseries info
        '''
        df["nextframeAcc"] = df.groupby(
            ["L-F_Pair"], as_index=False)["v_Acc"].shift(-1*n)
        df["nextframesvel"] = df.groupby(
            ["L-F_Pair"], as_index=False)["v_Vel"].shift(-1*n)
        df["nextframeposition"] = df.groupby(
            ["L-F_Pair"], as_index=False)["Local_Y"].shift(-1*n)
        df["nextFrameSpacing"] = df.groupby(
            ["L-F_Pair"], as_index=False)["Space_Gap"].shift(-1*n)
        df["precnextframesvel"] = df.groupby(
            ["L-F_Pair"], as_index=False)["v_Vel_preceding"].shift(-1*n)
        df = df[df['nextframeposition'].notna()]
        df = df[df['nextframesvel'].notna()]
        df = df[df['nextframeAcc'].notna()]
        df = df[df['nextFrameSpacing'].notna()]

        return df

# %%
train_df_5= create_prediction_columns(train_df, 5)
# Out:
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeAcc"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframesvel"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeposition"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextFrameSpacing"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["precnextframesvel"] = df.groupby(

# %%
train_df_5
# Out:
#         Vehicle_ID  Frame_ID     Local_Y  v_Length  v_Width  v_Class  \
# 0             1760      5683  425.375767   6.49224      8.5        3
# 1             1760      5682  423.323483   6.49224      8.5        3
# 2             1760      5681  421.265679   6.49224      8.5        3
# 3             1760      5680  419.201729   6.49224      8.5        3
# 4             1760      5679  417.131926   6.49224      8.5        3
# ...            ...       ...         ...       ...      ...      ...
# 341671        1749      7302  433.735630   5.73024      8.0        2
# 341673        1749      7303  435.146254   5.73024      8.0        2
# 341676        1749      7304  436.558090   5.73024      8.0        2
# 341678        1749      7305  437.971950   5.73024      8.0        2
# 341679        1749      7306  439.388279   5.73024      8.0        2
#
#             v_Vel     v_Acc  Lane_ID  Preceding  ...  pair_Time_Duration  \
# 0       20.498565 -0.283574        1       1754  ...                 0.0
# 1       20.547120 -0.474961        1       1754  ...                 0.1
# 2       20.608958 -0.491087        1       1754  ...                 0.2
# 3       20.670048 -0.463286        1       1754  ...                 0.3
# 4       20.725999 -0.777079        1       1754  ...                 0.4
# ...           ...       ...      ...        ...  ...                 ...
# 341671  14.102466  0.031511        1       1747  ...                32.4
# 341673  14.110007  0.119349        1       1747  ...                32.5
# 341676  14.126702  0.214642        1       1747  ...                32.6
# 341678  14.150506  0.261567        1       1747  ...                32.7
# 341679  14.176072  0.249886        1       1747  ...                32.8
#
#         total_pair_duration  Vehicle_Class  Space_Gap  Difference_of_speed  \
# 0                      11.6  Heavy Vehicle  36.277296             1.090135
# 1                      11.6  Heavy Vehicle  36.030408             1.327031
# 2                      11.6  Heavy Vehicle  35.920680             1.527489
# 3                      11.6  Heavy Vehicle  35.832288             1.700222
# 4                      11.6  Heavy Vehicle  35.814000             1.844612
# ...                     ...            ...        ...                  ...
# 341671                 33.3            Car  26.523696             1.577324
# 341673                 33.3            Car  26.508456             1.462328
# 341676                 33.3            Car  26.545032             1.309236
# 341678                 33.3            Car  26.618184             1.121355
# 341679                 33.3            Car  26.724864             0.906788
#
#         nextframeAcc  nextframesvel  nextframeposition  nextFrameSpacing  \
# 0          -0.679115      20.775275         415.056862         35.911536
# 1          -0.626724      20.899921         412.973103         35.856672
# 2          -0.649260      20.943266         410.880943         35.728656
# 3          -0.481942      20.991363         408.784212         35.661600
# 4          -0.714591      21.120779         404.573626         35.585400
# ...              ...            ...                ...               ...
# 341671      0.212091      14.199165         440.807041         26.862024
# 341673      0.184687      14.218998         442.227949         27.008328
# 341676      0.165098      14.236483         443.650723         27.166824
# 341678      0.087992      14.249134         445.075004         27.322272
# 341679      0.141147      14.260588         446.500490         27.462480
#
#         precnextframesvel
# 0               22.732894
# 1               22.853260
# 2               22.929306
# 3               22.960584
# 4               22.892418
# ...                   ...
# 341671          14.872017
# 341673          14.641252
# 341676          14.391028
# 341678          14.121275
# 341679          13.832364
#
# [264779 rows x 33 columns]

# %%
test_df_5= create_prediction_columns(test_df, 5)
# Out:
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeAcc"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframesvel"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeposition"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextFrameSpacing"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["precnextframesvel"] = df.groupby(

# %%
test_df_5
# Out:
#         Vehicle_ID  Frame_ID     Local_Y  v_Length  v_Width  v_Class  \
# 2029          1728      5460  199.176151   4.99872      4.9        2
# 2030          1728      5459  197.063314   4.99872      4.9        2
# 2031          1728      5458  194.950155   4.99872      4.9        2
# 2032          1728      5457  192.837061   4.99872      4.9        2
# 2033          1728      5456  190.724215   4.99872      4.9        2
# ...            ...       ...         ...       ...      ...      ...
# 341696        1755      7317  432.553507   5.42544      8.4        2
# 341697        1755      7318  433.951878   5.42544      8.4        2
# 341698        1755      7319  435.352370   5.42544      8.4        2
# 341699        1755      7320  436.755413   5.42544      8.4        2
# 341700        1755      7321  438.161510   5.42544      8.4        2
#
#             v_Vel     v_Acc  Lane_ID  Preceding  ...  pair_Time_Duration  \
# 2029    21.125748 -0.136463        1       1719  ...                 0.0
# 2030    21.130999 -0.060278        1       1719  ...                 0.1
# 2031    21.132177  0.016128        1       1719  ...                 0.2
# 2032    21.129697  0.076817        1       1719  ...                 0.3
# 2033    21.127232  0.005575        1       1719  ...                 0.4
# ...           ...       ...      ...        ...  ...                 ...
# 341696  13.974013  0.180951        1       1749  ...                31.9
# 341697  13.993415  0.207085        1       1749  ...                32.0
# 341698  14.016417  0.252962        1       1749  ...                32.1
# 341699  14.044461  0.307920        1       1749  ...                32.2
# 341700  14.077477  0.352398        1       1749  ...                32.3
#
#         total_pair_duration Vehicle_Class  Space_Gap  Difference_of_speed  \
# 2029                   17.7           Car  29.970984            -0.380847
# 2030                   17.7           Car  30.144720            -0.281815
# 2031                   17.7           Car  30.233112            -0.221334
# 2032                   17.7           Car  30.263592            -0.156960
# 2033                   17.7           Car  30.144720            -0.093838
# ...                     ...           ...        ...                  ...
# 341696                 32.8           Car  16.831056             1.133864
# 341697                 32.8           Car  16.821912             1.212407
# 341698                 32.8           Car  16.843248             1.254982
# 341699                 32.8           Car  16.858488             1.260305
# 341700                 32.8           Car  16.837152             1.229260
#
#         nextframeAcc  nextframesvel  nextframeposition  nextFrameSpacing  \
# 2029       -0.048618      21.130437         188.611331         30.150816
# 2030       -0.050103      21.137789         186.497920         30.099000
# 2031       -0.098274      21.148839         184.383588         29.986224
# 2032       -0.468500      21.165475         182.267873         29.873448
# 2033       -0.159886      21.177972         180.150700         29.855160
# ...              ...            ...                ...               ...
# 341696      0.372719      14.113733         439.571071         16.773144
# 341697      0.369981      14.150868         440.984301         16.684752
# 341698      0.370157      14.187875         442.401238         16.605504
# 341699      0.568790      14.234822         443.822373         16.565880
# 341700      1.250826      14.325803         445.250404         16.596360
#
#         precnextframesvel
# 2029            21.088028
# 2030            21.132877
# 2031            21.169068
# 2032            21.199559
# 2033            21.224840
# ...                   ...
# 341696          15.278563
# 341697          15.222014
# 341698          15.138900
# 341699          15.030022
# 341700          14.895152
#
# [70465 rows x 33 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
X_train = train_df_5.drop(['nextframesvel', 'Vehicle_Class', 'Location', 'Period', 'L-F_Pair'], axis = 1)
y_train = train_df_5['nextframesvel']
X_test = test_df_5.drop(['nextframesvel', 'Vehicle_Class', 'Location', 'Period', 'L-F_Pair'], axis = 1)
y_test = test_df_5['nextframesvel']
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(X_test, y_test)
# Out:
# 0.9867775916111909

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 0.5024164233131341

# %% [markdown]
# ### reaction of 1 sec

# %%
train_df_10= create_prediction_columns(train_df, 10)
# Out:
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeAcc"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframesvel"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeposition"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextFrameSpacing"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["precnextframesvel"] = df.groupby(

# %%
test_df_10= create_prediction_columns(test_df, 10)
# Out:
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeAcc"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframesvel"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeposition"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextFrameSpacing"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["precnextframesvel"] = df.groupby(

# %%
rf = RandomForestRegressor()
X_train = train_df_10.drop(['nextframesvel', 'Vehicle_Class', 'Location', 'Period', 'L-F_Pair'], axis = 1)
y_train = train_df_10['nextframesvel']
X_test = test_df_10.drop(['nextframesvel', 'Vehicle_Class', 'Location', 'Period', 'L-F_Pair'], axis = 1)
y_test = test_df_10['nextframesvel']
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(X_test, y_test)
# Out:
# 0.9779908475367977

# %%
y_pred = rf.predict(X_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 0.6475765972934567

# %% [markdown]
# ### reaction time of 1.5 s

# %%
train_df_15= create_prediction_columns(train_df, 15)
# Out:
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeAcc"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframesvel"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeposition"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextFrameSpacing"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["precnextframesvel"] = df.groupby(

# %%
test_df_15= create_prediction_columns(test_df, 15)
# Out:
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeAcc"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframesvel"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeposition"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextFrameSpacing"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["precnextframesvel"] = df.groupby(

# %%
rf = RandomForestRegressor()
X_train = train_df_15.drop(['nextframesvel', 'Vehicle_Class', 'Location', 'Period', 'L-F_Pair'], axis = 1)
y_train = train_df_15['nextframesvel']
X_test = test_df_15.drop(['nextframesvel', 'Vehicle_Class', 'Location', 'Period', 'L-F_Pair'], axis = 1)
y_test = test_df_15['nextframesvel']
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(X_test, y_test)
# Out:
# 0.9713872839102696

# %%
y_pred = rf.predict(X_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 0.7375556346351347

# %% [markdown]
# ### reaction time of 2s

# %%
train_df_20= create_prediction_columns(train_df, 20)
# Out:
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeAcc"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframesvel"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeposition"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextFrameSpacing"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["precnextframesvel"] = df.groupby(

# %%
test_df_20= create_prediction_columns(test_df, 20)
# Out:
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeAcc"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframesvel"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextframeposition"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["nextFrameSpacing"] = df.groupby(
# C:\Users\SUMIT VERMA\AppData\Local\Temp\ipykernel_25020\852587755.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["precnextframesvel"] = df.groupby(

# %%
rf = RandomForestRegressor()
X_train = train_df_20.drop(['nextframesvel', 'Vehicle_Class', 'Location', 'Period', 'L-F_Pair'], axis = 1)
y_train = train_df_20['nextframesvel']
X_test = test_df_20.drop(['nextframesvel', 'Vehicle_Class', 'Location', 'Period', 'L-F_Pair'], axis = 1)
y_test = test_df_20['nextframesvel']
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(X_test, y_test)
# Out:
# 0.9627907975671959

# %%
y_pred = rf.predict(X_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 0.8403241085457948
