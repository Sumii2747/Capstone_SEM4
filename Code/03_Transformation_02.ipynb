# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("merged.csv")
df.tail()
# Out:
#          Unnamed: 0  Vehicle_ID  Frame_ID  Total_Frames    Global_Time  \
# 1273223     1273223        1757      6959          1386  1113438260800
# 1273224     1273224        1757      6960          1386  1113438260900
# 1273225     1273225        1757      6961          1386  1113438261000
# 1273226     1273226        1757      6962          1386  1113438261100
# 1273227     1273227        1757      6963          1386  1113438261200
#
#           Local_X     Local_Y     Global_X     Global_Y  v_Length  ...  \
# 1273223  8.936736  199.600498  6042779.679  2133721.623   9.23544  ...
# 1273224  8.936736  199.600498  6042779.679  2133721.623   9.23544  ...
# 1273225  8.936736  199.600498  6042779.679  2133721.623   9.23544  ...
# 1273226  8.936736  199.600498  6042779.679  2133721.623   9.23544  ...
# 1273227  8.936736  199.600498  6042779.684  2133721.583   9.23544  ...
#
#          v_Class_preceding  v_Vel_preceding  v_Acc_preceding  \
# 1273223                  2         1.921670         0.278867
# 1273224                  2         1.950145         0.283335
# 1273225                  2         1.979865         0.303436
# 1273226                  2         2.012205         0.335061
# 1273227                  2         2.047770         0.367108
#
#          Lane_ID_preceding  Preceding_preceding  Following_preceding  \
# 1273223                  3                 1735                 1757
# 1273224                  3                 1735                 1757
# 1273225                  3                 1735                 1757
# 1273226                  3                 1735                 1757
# 1273227                  3                 1735                 1757
#
#          Space_Headway_preceding  Time_Headway_preceding  Location_preceding  \
# 1273223                12.371832                    5.69                 i80
# 1273224                12.405360                    4.66                 i80
# 1273225                12.380976                    4.20                 i80
# 1273226                12.335256                    4.04                 i80
# 1273227                12.298680                    4.01                 i80
#
#         Period_preceding
# 1273223  5:15PM - 5:30PM
# 1273224  5:15PM - 5:30PM
# 1273225  5:15PM - 5:30PM
# 1273226  5:15PM - 5:30PM
# 1273227  5:15PM - 5:30PM
#
# [5 rows x 40 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Vehicle_ID', 'Frame_ID', 'Total_Frames', 'Global_Time',
#        'Local_X', 'Local_Y', 'Global_X', 'Global_Y', 'v_Length', 'v_Width',
#        'v_Class', 'v_Vel', 'v_Acc', 'Lane_ID', 'Preceding', 'Following',
#        'Space_Headway', 'Time_Headway', 'Location', 'Period',
#        'Vehicle_ID_preceding', 'Total_Frames_preceding',
#        'Global_Time_preceding', 'Local_X_preceding', 'Local_Y_preceding',
#        'Global_X_preceding', 'Global_Y_preceding', 'v_Length_preceding',
#        'v_Width_preceding', 'v_Class_preceding', 'v_Vel_preceding',
#        'v_Acc_preceding', 'Lane_ID_preceding', 'Preceding_preceding',
#        'Following_preceding', 'Space_Headway_preceding',
#        'Time_Headway_preceding', 'Location_preceding', 'Period_preceding'],
#       dtype='object')

# %%
df = df.drop(['Preceding_preceding','Following_preceding','Local_X_preceding', 'Local_Y_preceding',
              'Global_X_preceding', 'Global_Y_preceding','Total_Frames_preceding',
              'Unnamed: 0', 'Location_preceding', 'Period_preceding'],axis=1)

# %%
# So , for proper knowing the Vehicle type we are assigning the v_class with Vehicle class
 #   1 L Motorcycle   2: Car     3: Heavy Vehicle
    
filtered_vClass = df[['Vehicle_ID', 'v_Class', 'v_Length']].drop_duplicates().sort_values('v_Class')

class_mapping = {1: 'Motorcycle', 2: 'Car', 3: 'Heavy Vehicle'}

df['Vehicle_Class'] = df['v_Class'].map(class_mapping)

# %% [markdown]
# ### Calculating the space gap by subtracting the length of the preceding vehicle from the space headway using the following code

# %%
# Calculate the space gap 

df['Space_Gap'] = df['Space_Headway'] - df['v_Length_preceding']

# %%
# Define the reaction times in seconds

df['Difference_of_speed'] = df['v_Vel_preceding'] - df['v_Vel']

# %%
df
# Out:
#          Vehicle_ID  Frame_ID  Total_Frames    Global_Time   Local_X  \
# 0                 2       372           415  1113433172100  1.737970
# 1                 2       373           415  1113433172200  1.742846
# 2                 2       374           415  1113433172300  1.748028
# 3                 2       375           415  1113433172400  1.753210
# 4                 2       376           415  1113433172500  1.758086
# ...             ...       ...           ...            ...       ...
# 1273223        1757      6959          1386  1113438260800  8.936736
# 1273224        1757      6960          1386  1113438260900  8.936736
# 1273225        1757      6961          1386  1113438261000  8.936736
# 1273226        1757      6962          1386  1113438261100  8.936736
# 1273227        1757      6963          1386  1113438261200  8.936736
#
#             Local_Y     Global_X     Global_Y  v_Length  v_Width  ...  \
# 0         29.656915  6042825.039  2133164.183   4.66344      6.4  ...
# 1         29.798545  6042824.992  2133164.698   4.66344      6.4  ...
# 2         29.925816  6042824.945  2133165.213   4.66344      6.4  ...
# 3         30.038956  6042824.898  2133165.728   4.66344      6.4  ...
# 4         30.139771  6042824.851  2133166.243   4.66344      6.4  ...
# ...             ...          ...          ...       ...      ...  ...
# 1273223  199.600498  6042779.679  2133721.623   9.23544      8.5  ...
# 1273224  199.600498  6042779.679  2133721.623   9.23544      8.5  ...
# 1273225  199.600498  6042779.679  2133721.623   9.23544      8.5  ...
# 1273226  199.600498  6042779.679  2133721.623   9.23544      8.5  ...
# 1273227  199.600498  6042779.684  2133721.583   9.23544      8.5  ...
#
#          v_Width_preceding  v_Class_preceding  v_Vel_preceding  \
# 0                      6.3                  2         1.113693
# 1                      6.3                  2         1.199905
# 2                      6.3                  2         1.296094
# 3                      6.3                  2         1.401743
# 4                      6.3                  2         1.515577
# ...                    ...                ...              ...
# 1273223                6.9                  2         1.921670
# 1273224                6.9                  2         1.950145
# 1273225                6.9                  2         1.979865
# 1273226                6.9                  2         2.012205
# 1273227                6.9                  2         2.047770
#
#          v_Acc_preceding  Lane_ID_preceding  Space_Headway_preceding  \
# 0               0.849915                  1                33.933384
# 1               0.955930                  1                34.216848
# 2               1.058899                  1                34.497264
# 3               1.154087                  1                34.832544
# 4               1.180521                  1                35.240976
# ...                  ...                ...                      ...
# 1273223         0.278867                  3                12.371832
# 1273224         0.283335                  3                12.405360
# 1273225         0.303436                  3                12.380976
# 1273226         0.335061                  3                12.335256
# 1273227         0.367108                  3                12.298680
#
#          Time_Headway_preceding  Vehicle_Class  Space_Gap Difference_of_speed
# 0                         40.93            Car  15.544800           -0.373262
# 1                         43.51            Car  15.468600           -0.145727
# 2                         48.37            Car  15.392400            0.096299
# 3                         57.43            Car  15.300960            0.338739
# 4                         68.41            Car  15.194280            0.562273
# ...                         ...            ...        ...                 ...
# 1273223                    5.69  Heavy Vehicle  43.921680            1.921670
# 1273224                    4.66  Heavy Vehicle  44.159424            1.950145
# 1273225                    4.20  Heavy Vehicle  44.455080            1.979865
# 1273226                    4.04  Heavy Vehicle  44.769024            2.012205
# 1273227                    4.01  Heavy Vehicle  45.076872            2.047770
#
# [1273228 rows x 33 columns]

# %%
df.to_csv("Transformation_2.csv")
