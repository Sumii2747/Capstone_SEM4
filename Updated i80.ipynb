# %%
import pandas as pd 
import numpy as np

# %%
df_1 =  pd.read_csv("EMD_Reconstructed(i80 0400-0415).csv")
df_2 =  pd.read_csv("EMD_Reconstructed(i80 0500-0515).csv")
df_3 =  pd.read_csv("EMD_Reconstructed(i80 0515-0530).csv")

# %%
df_1
# Out:
#          Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X  \
# 0                 1        12           884  1113433136100   16.884
# 1                 1        13           884  1113433136200   16.938
# 2                 1        14           884  1113433136300   16.991
# 3                 1        15           884  1113433136400   17.045
# 4                 1        16           884  1113433136500   17.098
# ...             ...       ...           ...            ...      ...
# 1048570        2911      8588           731  1113433993700   53.693
# 1048571        2911      8589           731  1113433993800   53.719
# 1048572        2911      8590           731  1113433993900   53.746
# 1048573        2911      8591           731  1113433994000   53.772
# 1048574        2911      8592           731  1113433994100   53.799
#
#              Local_Y     Global_X     Global_Y  v_Length  v_Width  v_Class  \
# ...

# %% [markdown]
# # Adding a new column in all i80 dataset

# %%
num_rows = df_1.shape[0]
df_1["Location"] = ['i80']*num_rows
df_1["Period"] = ['4:00PM - 4:15PM']*num_rows
df_1.head()
# Out:
#    Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X    Local_Y  \
# 0           1        12           884  1113433136100   16.884  52.747821
# 1           1        13           884  1113433136200   16.938  53.454997
# 2           1        14           884  1113433136300   16.991  54.190893
# 3           1        15           884  1113433136400   17.045  54.961816
# 4           1        16           884  1113433136500   17.098  55.771003
#
#       Global_X     Global_Y  v_Length  v_Width  v_Class     v_Vel     v_Acc  \
# 0  6042842.116  2133117.662      14.3      6.4        2  6.947704  2.188888
# 1  6042842.012  2133118.909      14.3      6.4        2  7.195818  3.152102
# 2  6042841.908  2133120.155      14.3      6.4        2  7.522104  3.871618
# 3  6042841.805  2133121.402      14.3      6.4        2  7.896343  4.184370
# 4  6042841.701  2133122.649      14.3      6.4        2  8.287402  3.906572
#
# ...

# %%
df_2["Location"] = ['i80']*num_rows
df_2["Period"] = ['5:00PM - 5:15PM']*num_rows
df_2.head()
# Out:
#    Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X    Local_Y  \
# 0         284        63           526  1113436773200   41.375  83.945174
# 1         284        64           526  1113436773300   41.375  86.630512
# 2         284        65           526  1113436773400   41.374  89.397060
# 3         284        66           526  1113436773500   41.373  92.262882
# 4         284        67           526  1113436773600   41.372  95.237186
#
#       Global_X     Global_Y  v_Length  v_Width  v_Class      v_Vel      v_Acc  \
# 0  6042864.125  2133138.844      15.4      5.9        2  26.503468   5.673412
# 1  6042863.571  2133143.309      15.4      5.9        2  27.203295   8.238863
# 2  6042863.016  2133147.775      15.4      5.9        2  28.127674  10.137441
# 3  6042862.462  2133152.241      15.4      5.9        2  29.188753  10.956390
# 4  6042861.904  2133156.736      15.4      5.9        2  30.297327  11.081609
#
# ...

# %%
df_3["Location"] = ['i80']*num_rows
df_3["Period"] = ['5:15PM - 5:30PM']*num_rows
df_3.head()
# Out:
#    Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X    Local_Y  \
# 0           3       613          1153  1113437626200   28.369  67.290627
# 1           3       614          1153  1113437626300   28.370  67.789941
# 2           3       615          1153  1113437626400   28.372  68.303695
# 3           3       616          1153  1113437626500   28.374  68.834859
# 4           3       617          1153  1113437626600   28.375  69.385326
#
#       Global_X     Global_Y  v_Length  v_Width  v_Class     v_Vel     v_Acc  \
# 0  6042851.531  2133134.762      12.8      6.8        2  4.929700  1.064082
# 1  6042851.469  2133135.258      12.8      6.8        2  5.056585  1.453711
# 2  6042851.346  2133136.250      12.8      6.8        2  5.218489  1.758948
# 3  6042851.223  2133137.243      12.8      6.8        2  5.404807  1.938183
# 4  6042851.143  2133137.889      12.8      6.8        2  5.604517  2.024664
#
# ...

# %%
df_1['Period'].unique()
# Out:
# array(['4:00PM - 4:15PM'], dtype=object)

# %%
df_1.to_csv('Updated_i80(04-0415).csv', index = False)
df_2.to_csv('Updated_i80(05-0515).csv', index = False)

# %%
df_3.to_csv("Updated_i80(0515-0530).csv", index = False)

# %% [markdown]
# ## Combining all updated datasets in one(i80)

# %%
# Combine the datasets
combined_i80 = pd.concat([df_1,df_2,df_3], axis=0)

# Reset the index of the combined dataset
combined_i80.reset_index(drop=True, inplace=True)
combined_i80
# Out:
#          Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X  \
# 0                 1        12           884  1113433136100   16.884
# 1                 1        13           884  1113433136200   16.938
# 2                 1        14           884  1113433136300   16.991
# 3                 1        15           884  1113433136400   17.045
# 4                 1        16           884  1113433136500   17.098
# ...             ...       ...           ...            ...      ...
# 3145720        1757      6959          1386  1113438260800   29.320
# 3145721        1757      6960          1386  1113438260900   29.320
# 3145722        1757      6961          1386  1113438261000   29.320
# 3145723        1757      6962          1386  1113438261100   29.320
# 3145724        1757      6963          1386  1113438261200   29.320
#
#             Local_Y     Global_X     Global_Y  v_Length  v_Width  v_Class  \
# 0         52.747821  6042842.116  2133117.662      14.3      6.4        2
# ...

# %%
combined_i80.to_csv("Combined_i80.csv", index = False)
