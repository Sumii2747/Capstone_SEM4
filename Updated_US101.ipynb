# %%
import pandas as pd 
import numpy as np

# %%
df_1 =  pd.read_csv("EMD_Reconstructed(us-101 0750am-0805am).csv")
df_2 =  pd.read_csv("EMD_Reconstructed(us-101 0805am-0820am).csv")
df_3 =  pd.read_csv("EMD_Reconstructed(us-101 0820am-0835am).csv")

# %%
df_1
# Out:
#          Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X  \
# 0                 2        13           437  1118846980200   16.467
# 1                 2        14           437  1118846980300   16.447
# 2                 2        15           437  1118846980400   16.426
# 3                 2        16           437  1118846980500   16.405
# 4                 2        17           437  1118846980600   16.385
# ...             ...       ...           ...            ...      ...
# 1048570        2783      8698           760  1118847848700   55.108
# 1048571        2783      8699           760  1118847848800   55.032
# 1048572        2783      8700           760  1118847848900   55.044
# 1048573        2783      8701           760  1118847849000   55.133
# 1048574        2783      8702           760  1118847849100   55.168
#
#              Local_Y     Global_X     Global_Y  v_Length  v_Width  v_Class  \
# ...

# %% [markdown]
# # Adding two column in us 101 datasets

# %%
num_rows = df_1.shape[0]
df_1["Location"] = ['us101']*num_rows
df_1["Period"] = ['7:50AM - 8:05AM']*num_rows
df_1.head()
# Out:
#    Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X    Local_Y  \
# 0           2        13           437  1118846980200   16.467  49.632144
# 1           2        14           437  1118846980300   16.447  51.663558
# 2           2        15           437  1118846980400   16.426  53.776399
# 3           2        16           437  1118846980500   16.405  55.989720
# 4           2        17           437  1118846980600   16.385  58.311420
#
#       Global_X     Global_Y  v_Length  v_Width  v_Class      v_Vel      v_Acc  \
# 0  6451137.641  1873344.962      14.5      4.9        2  19.968408   5.483250
# 1  6451140.329  1873342.000      14.5      4.9        2  20.659887   8.284013
# 2  6451143.018  1873339.038      14.5      4.9        2  21.596919  10.372190
# 3  6451145.706  1873336.077      14.5      4.9        2  22.669500  10.982768
# 4  6451148.395  1873333.115      14.5      4.9        2  23.764500  10.818539
#
# ...

# %%
df_2["Location"] = ['us101']*num_rows
df_2["Period"] = ['8:05AM- 8:20AM']*num_rows
df_2.head()
# Out:
#    Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X     Local_Y  \
# 0           1       270           569  1118847869000   51.164  119.654025
# 1           1       271           569  1118847869100   51.153  120.668400
# 2           1       272           569  1118847869200   51.143  121.724280
# 3           1       273           569  1118847869300   51.244  122.831158
# 4           1       274           569  1118847869400   51.234  123.994261
#
#       Global_X     Global_Y  v_Length  v_Width  v_Class      v_Vel     v_Acc  \
# 0  6451136.708  1873294.084      47.0      8.5        3   9.965173  2.893582
# 1  6451138.053  1873292.603      47.0      8.5        3  10.322331  4.192748
# 2  6451139.397  1873291.122      47.0      8.5        3  10.795264  5.190666
# 3  6451140.617  1873289.614      47.0      8.5        3  11.342302  5.663074
# 4  6451141.961  1873288.133      47.0      8.5        3  11.919764  5.794288
#
# ...

# %%
df_3["Location"] = ['us101']*num_rows
df_3["Period"] = ['8:20AM- 8:35AM']*num_rows
df_3.head()
# Out:
#    Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X    Local_Y  \
# 0           1       137           421  1118848770700   52.660  82.706652
# 1           1       138           421  1118848770800   52.648  84.017251
# 2           1       139           421  1118848770900   52.635  85.382542
# 3           1       140           421  1118848771000   52.622  86.815120
# 4           1       141           421  1118848771100   52.609  88.320485
#
#       Global_X     Global_Y  v_Length  v_Width  v_Class      v_Vel     v_Acc  \
# 0  6451113.236  1873317.970      15.0      6.4        2  12.872914  4.016778
# 1  6451114.916  1873316.119      15.0      6.4        2  13.339072  6.019351
# 2  6451116.596  1873314.268      15.0      6.4        2  13.966749  7.494230
# 3  6451118.277  1873312.417      15.0      6.4        2  14.684810  7.965254
# 4  6451119.957  1873310.566      15.0      6.4        2  15.422476  7.294709
#
# ...

# %%
df_1.to_csv('Updated_us101(0750-0805).csv')
df_2.to_csv('Updated_us101(0805-0820).csv')
df_3.to_csv('Updated_us101(0820-0835).csv')

# %% [markdown]
# ## Combining all updated datasets in one(us-101)

# %%
# Combine the datasets
combined_us101 = pd.concat([df_1,df_2,df_3], axis=0)

# Reset the index of the combined dataset
combined_us101.reset_index(drop=True, inplace=True)
combined_us101
# Out:
#          Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X  \
# 0                 2        13           437  1118846980200   16.467
# 1                 2        14           437  1118846980300   16.447
# 2                 2        15           437  1118846980400   16.426
# 3                 2        16           437  1118846980500   16.405
# 4                 2        17           437  1118846980600   16.385
# ...             ...       ...           ...            ...      ...
# 3145720        1317      6107          1114  1118849367700   38.320
# 3145721        1317      6108          1114  1118849367800   38.353
# 3145722        1317      6109          1114  1118849367900   38.393
# 3145723        1317      6110          1114  1118849368000   38.418
# 3145724        1317      6111          1114  1118849368100   38.405
#
#             Local_Y     Global_X     Global_Y  v_Length  v_Width  v_Class  \
# 0         49.632144  6451137.641  1873344.962      14.5      4.9        2
# ...

# %%
combined_us101.to_csv("Combined_us101.csv", index = False)

# %%
df = pd.read_csv("Combined_us101.csv")

# %%
df['Lane_ID'].unique()
# Out:
# array([2, 1, 7, 6, 5, 4, 3, 8], dtype=int64)
